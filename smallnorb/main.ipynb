# %%
import sys
sys.path.insert(0, '../')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from dataset import SmallNORBDataset

# %% [markdown]
# ### dataset = SmallNORBDataset('../datasets/SmallNORB')

# %%
dataset = SmallNORBDataset('../datasets/SmallNORB/')
# Out:
# ...
# Loading info...: 100%|██████████| 24300/24300 [00:00<00:00, 384766.57it/s]

# %%
plt.imshow(dataset.data['train'][9].image_rt, cmap='gray')

# %%
dataset.data['train']
# Out:
# ...
#  ...]
